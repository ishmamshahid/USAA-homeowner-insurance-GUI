# %%
# Reimport necessary libraries and create the dataframe again after the reset
import pandas as pd

# Define the column names as specified
columns = ['Term', 'Number of Days', 'Other Perils', 'Fire', 'Other Wind and Hail', 'Theft', 'Water', 
           'Liability', 'Hurricane', 'Severe Thunderstorm', 'Winter Storm', 'Earthquake']

# Define the data provided
data = [
    [0, '0', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [0, '1-6', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [0, '7+', 0.850, 0.850, 0.850, 0.850, 0.850, 0.850, 0.850, 0.850, 0.850, 0.850],
    [1, '0', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [1, '1-6', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [1, '7+', 0.880, 0.880, 0.880, 0.880, 0.880, 0.880, 0.880, 0.880, 0.880, 0.880],
    [2, '0', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [2, '1-6', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [2, '7+', 0.910, 0.910, 0.910, 0.910, 0.910, 0.910, 0.910, 0.910, 0.910, 0.910],
    [3, '0', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [3, '1-6', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [3, '7+', 0.940, 0.940, 0.940, 0.940, 0.940, 0.940, 0.940, 0.940, 0.940, 0.940],
    [4, '0', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [4, '1-6', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    [4, '7+', 0.970, 0.970, 0.970, 0.970, 0.970, 0.970, 0.970, 0.970, 0.970, 0.970],
    ['5+', '0', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    ['5+', '1-6', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000],
    ['5+', '7+', 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000, 1.000]
]

# Create the DataFrame
df = pd.DataFrame(data, columns=columns)

df
# Out:
#    Term Number of Days  Other Perils  Fire  Other Wind and Hail  Theft  Water  \
# 0     0              0          1.00  1.00                 1.00   1.00   1.00
# 1     0            1-6          1.00  1.00                 1.00   1.00   1.00
# 2     0             7+          0.85  0.85                 0.85   0.85   0.85
# 3     1              0          1.00  1.00                 1.00   1.00   1.00
# 4     1            1-6          1.00  1.00                 1.00   1.00   1.00
# 5     1             7+          0.88  0.88                 0.88   0.88   0.88
# 6     2              0          1.00  1.00                 1.00   1.00   1.00
# 7     2            1-6          1.00  1.00                 1.00   1.00   1.00
# 8     2             7+          0.91  0.91                 0.91   0.91   0.91
# 9     3              0          1.00  1.00                 1.00   1.00   1.00
# 10    3            1-6          1.00  1.00                 1.00   1.00   1.00
# ...

# %%
df.to_csv("D:\\LSU\\Research\\wind_ins\\USAA-134022151\\output_tables\\Owner\\32_early_quote_discount.csv", index=False)
