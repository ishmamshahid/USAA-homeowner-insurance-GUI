# %%
import pandas as pd

# Creating data for both Min sq ft and Max sq ft columns based on the uploaded images
data = {
    "Min sq ft": [
        0, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 
        2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 
        4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5500, 6000, 6500, 7000, 7500, 10000
    ],
    "Max sq ft": [
        499, 599, 699, 799, 899, 999, 1099, 1199, 1299, 1399, 1499, 1599, 1699, 1799, 1899, 1999, 2099, 2199, 2299, 
        2399, 2499, 2599, 2699, 2799, 2899, 2999, 3099, 3199, 3299, 3399, 3499, 3599, 3699, 3799, 3899, 3999, 4099, 
        4199, 4299, 4399, 4499, 4599, 4699, 4799, 4899, 4999, 5499, 5999, 6499, 6999, 7499, 9999, '>10000'
    ]
}

# Creating the dataframe
sq_ft = pd.DataFrame(data)

ones_df = pd.DataFrame(1, index=range(53), columns=['1', '1.5', '2', '2.5', '3+'])

# %%
other_perils = pd.concat([sq_ft, ones_df], axis=1)

other_perils.insert(0, 'Peril', 'Other Perils')
other_perils
# Out:
#            Peril  Min sq ft Max sq ft  1  1.5  2  2.5  3+
# 0   Other Perils          0       499  1    1  1    1   1
# 1   Other Perils        500       599  1    1  1    1   1
# 2   Other Perils        600       699  1    1  1    1   1
# 3   Other Perils        700       799  1    1  1    1   1
# 4   Other Perils        800       899  1    1  1    1   1
# 5   Other Perils        900       999  1    1  1    1   1
# 6   Other Perils       1000      1099  1    1  1    1   1
# 7   Other Perils       1100      1199  1    1  1    1   1
# 8   Other Perils       1200      1299  1    1  1    1   1
# 9   Other Perils       1300      1399  1    1  1    1   1
# 10  Other Perils       1400      1499  1    1  1    1   1
# 11  Other Perils       1500      1599  1    1  1    1   1
# 12  Other Perils       1600      1699  1    1  1    1   1
# 13  Other Perils       1700      1799  1    1  1    1   1
# 14  Other Perils       1800      1899  1    1  1    1   1
# ...

# %%
fire = pd.concat([sq_ft, ones_df], axis=1)

fire.insert(0, 'Peril', 'Fire')
fire
# Out:
#    Peril  Min sq ft Max sq ft  1  1.5  2  2.5  3+
# 0   Fire          0       499  1    1  1    1   1
# 1   Fire        500       599  1    1  1    1   1
# 2   Fire        600       699  1    1  1    1   1
# 3   Fire        700       799  1    1  1    1   1
# 4   Fire        800       899  1    1  1    1   1
# 5   Fire        900       999  1    1  1    1   1
# 6   Fire       1000      1099  1    1  1    1   1
# 7   Fire       1100      1199  1    1  1    1   1
# 8   Fire       1200      1299  1    1  1    1   1
# 9   Fire       1300      1399  1    1  1    1   1
# 10  Fire       1400      1499  1    1  1    1   1
# 11  Fire       1500      1599  1    1  1    1   1
# 12  Fire       1600      1699  1    1  1    1   1
# 13  Fire       1700      1799  1    1  1    1   1
# 14  Fire       1800      1899  1    1  1    1   1
# 15  Fire       1900      1999  1    1  1    1   1
# 16  Fire       2000      2099  1    1  1    1   1
# 17  Fire       2100      2199  1    1  1    1   1
# ...

# %%
liability = pd.concat([sq_ft, ones_df], axis=1)

liability.insert(0, 'Peril', 'Liability')
liability
# Out:
#         Peril  Min sq ft Max sq ft  1  1.5  2  2.5  3+
# 0   Liability          0       499  1    1  1    1   1
# 1   Liability        500       599  1    1  1    1   1
# 2   Liability        600       699  1    1  1    1   1
# 3   Liability        700       799  1    1  1    1   1
# 4   Liability        800       899  1    1  1    1   1
# 5   Liability        900       999  1    1  1    1   1
# 6   Liability       1000      1099  1    1  1    1   1
# 7   Liability       1100      1199  1    1  1    1   1
# 8   Liability       1200      1299  1    1  1    1   1
# 9   Liability       1300      1399  1    1  1    1   1
# 10  Liability       1400      1499  1    1  1    1   1
# 11  Liability       1500      1599  1    1  1    1   1
# 12  Liability       1600      1699  1    1  1    1   1
# 13  Liability       1700      1799  1    1  1    1   1
# 14  Liability       1800      1899  1    1  1    1   1
# 15  Liability       1900      1999  1    1  1    1   1
# ...

# %%
data = pd.read_csv("D:\\LSU\\Research\\wind_ins\\USAA-134022151\\Book1.csv")

# %%
sq_ftxnum_stories = pd.concat([other_perils, fire, liability, data], ignore_index= True)

# %%
sq_ftxnum_stories
# Out:
#             Peril  Min sq ft Max sq ft    1  1.5      2    2.5     3+
# 0    Other Perils          0       499  1.0  1.0  1.000  1.000  1.000
# 1    Other Perils        500       599  1.0  1.0  1.000  1.000  1.000
# 2    Other Perils        600       699  1.0  1.0  1.000  1.000  1.000
# 3    Other Perils        700       799  1.0  1.0  1.000  1.000  1.000
# 4    Other Perils        800       899  1.0  1.0  1.000  1.000  1.000
# ..            ...        ...       ...  ...  ...    ...    ...    ...
# 525    Earthquake       6000      6499  1.0  1.0  1.766  1.766  1.766
# 526    Earthquake       6500      6999  1.0  1.0  1.766  1.766  1.766
# 527    Earthquake       7000      7499  1.0  1.0  1.766  1.766  1.766
# 528    Earthquake       7500      9999  1.0  1.0  1.766  1.766  1.766
# 529    Earthquake      10000    >10000  1.0  1.0  1.766  1.766  1.766
#
# [530 rows x 8 columns]

# %%
sq_ftxnum_stories .to_csv("D:\\LSU\\Research\\wind_ins\\USAA-134022151\\output_tables\\Owner\\23_sq_ftxnum_stories.csv", index=False)
